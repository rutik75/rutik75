# %% [markdown]
# <a href="https://colab.research.google.com/github/rutik75/rutik75/blob/main/Internship.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
true = pd.read_csv('True.csv')

# %%
fake = pd.read_csv('Fake.csv')

# %%
true.head()
# Out:
#                                                title  \
# 0  Cabinet Approves Four Railway Projects Worth ₹...
# 1  ISRO announces launch window for Gaganyaan hum...
#
#                                              content  label
# 0  The Union Cabinet approved four railway multi-...      1
# 1  ISRO has confirmed the launch window for the a...      1

# %%
fake.head()
# Out:
#                                                title  \
# 0  Scientists discover a portal to another dimens...
# 1  Government to provide every citizen with a fre...
#
#                                              content  label
# 0  Reports claim that researchers have discovered...      0
# 1  In a surprise move, the government announced t...      0

# %%
true['label']=1

# %%
fake['label']=0

# %%
true.head()
# Out:
#                                                title  \
# 0  Cabinet Approves Four Railway Projects Worth ₹...
# 1  ISRO announces launch window for Gaganyaan hum...
#
#                                              content  label
# 0  The Union Cabinet approved four railway multi-...      1
# 1  ISRO has confirmed the launch window for the a...      1

# %%
news = pd.concat([fake,true],axis=0)

# %%
news.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
news.tail()
# Out:
#                                                    title  \
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...  worldnews
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...  worldnews
# 21414  MINSK (Reuters) - In the shadow of disused Sov...  worldnews
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...  worldnews
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...  worldnews
#
#                    date  label
# 21412  August 22, 2017       1
# 21413  August 22, 2017       1
# 21414  August 22, 2017       1
# 21415  August 22, 2017       1
# 21416  August 22, 2017       1

# %%
news.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# label      0
# dtype: int64

# %%
news = news.drop(['title','subject','date'],axis=1)

# %%
news.head()
# Out:
#                                                 text  label
# 0  Donald Trump just couldn t wish all Americans ...      0
# 1  House Intelligence Committee Chairman Devin Nu...      0
# 2  On Friday, it was revealed that former Milwauk...      0
# 3  On Christmas day, Donald Trump announced that ...      0
# 4  Pope Francis used his annual Christmas Day mes...      0

# %%
news = news.sample(frac=1)            #reshuffling

# %%
news.head()
# Out:
#                                                     text  label
# 4402   BERLIN (Reuters) - The U.S. military strike on...      1
# 20702  Hillary s over-the-top plan to tax the consume...      0
# 18360  This group of Black Lives Matter supporters ma...      0
# 10007  What the heck happened to our freedom of speec...      0
# 9346   (Reuters) - At least five animal rights activi...      1

# %%
news.reset_index(inplace=True)

# %%
news.head()
# Out:
#    index                                               text  label
# 0   4402  BERLIN (Reuters) - The U.S. military strike on...      1
# 1  20702  Hillary s over-the-top plan to tax the consume...      0
# 2  18360  This group of Black Lives Matter supporters ma...      0
# 3  10007  What the heck happened to our freedom of speec...      0
# 4   9346  (Reuters) - At least five animal rights activi...      1

# %%
news.drop(['index'],axis=1,inplace = True)

# %%
news.head()
# Out:
#                                                 text  label
# 0  BERLIN (Reuters) - The U.S. military strike on...      1
# 1  Hillary s over-the-top plan to tax the consume...      0
# 2  This group of Black Lives Matter supporters ma...      0
# 3  What the heck happened to our freedom of speec...      0
# 4  (Reuters) - At least five animal rights activi...      1

# %%
import re

# %%
def wordopt(text):
    #Convert into lowercase
    text = text.lower()

    # Remove URLS
    text = re.sub(r'https?://\S+|www\.\S+','',text)

    # Remove HTML tags
    text = re.sub(r'<.*?>', '', text)

    # Remove punctuation
    text = re.sub(r'[^\w\s]', '', text)

    # Remove digits
    text = re.sub(r'\d', '', text)

    # Remove newline characters
    text = re.sub(r'\n', ' ', text)

    return text

# %%
news['text'] = news['text'].apply(wordopt)

# %%
news['text']
# Out:
# 0        berlin reuters  the us military strike on a sy...
# 1        hillary s overthetop plan to tax the consumer ...
# 2        this group of black lives matter supporters ma...
# 3        what the heck happened to our freedom of speec...
# 4        reuters  at least five animal rights activists...
#                                ...
# 44893    beirut reuters  fighters with the syrian kurdi...
# 44894    washington reuters  us senate democrats urged ...
# 44895    washington reuters  the white house said on tu...
# 44896    abuja reuters  more than  people have fled sou...
# 44897    former republican house intelligence cmte chai...
# Name: text, Length: 44898, dtype: object

# %%
x = news['text']
y = news['label']

# %%
x
# Out:
# 0        berlin reuters  the us military strike on a sy...
# 1        hillary s overthetop plan to tax the consumer ...
# 2        this group of black lives matter supporters ma...
# 3        what the heck happened to our freedom of speec...
# 4        reuters  at least five animal rights activists...
#                                ...
# 44893    beirut reuters  fighters with the syrian kurdi...
# 44894    washington reuters  us senate democrats urged ...
# 44895    washington reuters  the white house said on tu...
# 44896    abuja reuters  more than  people have fled sou...
# 44897    former republican house intelligence cmte chai...
# Name: text, Length: 44898, dtype: object

# %%
y
# Out:
# 0        1
# 1        0
# 2        0
# 3        0
# 4        1
#         ..
# 44893    1
# 44894    1
# 44895    1
# 44896    1
# 44897    0
# Name: label, Length: 44898, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3)

# %%
x_train.shape
# Out:
# (31428,)

# %%
x_test.shape
# Out:
# (13470,)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorization = TfidfVectorizer()

# %%
xv_train = vectorization.fit_transform(x_train)

# %%
xv_test = vectorization.transform(x_test)

# %%
xv_train
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 6449148 stored elements and shape (31428, 175148)>

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# %%
LR = LogisticRegression()

# %%
LR.fit(xv_train, y_train)
# Out:
# LogisticRegression()

# %%
pred_lr = LR.predict(xv_test)

# %%
LR.score(xv_test, y_test)
# Out:
# 0.9892353377876764

# %%
print(classification_report(y_test, pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      7087
#            1       0.99      0.99      0.99      6383
#
#     accuracy                           0.99     13470
#    macro avg       0.99      0.99      0.99     13470
# weighted avg       0.99      0.99      0.99     13470

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DTC = DecisionTreeClassifier()

# %%
DTC.fit(xv_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dtc = DTC.predict(xv_test)

# %%
DTC.score(xv_test, y_test)
# Out:
# 0.9964365256124722

# %%
print(classification_report(y_test,pred_dtc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7087
#            1       1.00      1.00      1.00      6383
#
#     accuracy                           1.00     13470
#    macro avg       1.00      1.00      1.00     13470
# weighted avg       1.00      1.00      1.00     13470

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()

# %%
rfc.fit(xv_train, y_train)
# Out:
# RandomForestClassifier()

# %%
predict_rfc = rfc.predict(xv_test)

# %%
rfc.score(xv_test, y_test)
# Out:
# 0.9883444691907943

# %%
print(classification_report(y_test,predict_rfc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      7087
#            1       0.99      0.99      0.99      6383
#
#     accuracy                           0.99     13470
#    macro avg       0.99      0.99      0.99     13470
# weighted avg       0.99      0.99      0.99     13470

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbc = GradientBoostingClassifier()

# %%
gbc.fit(xv_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
pred_gbc = gbc.predict(xv_test)

# %%
gbc.score(xv_test, y_test)
# Out:
# 0.9953971789161099

# %%
print(classification_report(y_test,pred_gbc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      7087
#            1       0.99      1.00      1.00      6383
#
#     accuracy                           1.00     13470
#    macro avg       1.00      1.00      1.00     13470
# weighted avg       1.00      1.00      1.00     13470

# %%
def output_label(n):
    if n == 0:
        return "It is a Fake News"
    elif n == 1:
        return "It is a Genuine News"

# %%
def manual_testing(news):
    testing_news = {"text": [news]}  # create a DataFrame with the input text
    new_def_test = pd.DataFrame(testing_news)
    new_def_test["text"] = new_def_test["text"].apply(wordopt)  # preprocess
    new_x_test = new_def_test["text"]

    new_xv_test = vectorization.transform(new_x_test)  # vectorize the text

    pred_lr = LR.predict(new_xv_test)
    pred_gbc = gbc.predict(new_xv_test)
    pred_rfc = rfc.predict(new_xv_test)

    return "\n\nLR Prediction: {} \nGBC Prediction: {} \nRFC Prediction: {}".format(
        output_label(pred_lr[0]),
        output_label(pred_gbc[0]),
        output_label(pred_rfc[0])
    )

# %%
news_article = str(input())
# Out:
# India won a total of 107 medals, including 28 golds, at the 2023 Asian Games held in Hangzhou, China. This marked India's best-ever performance at the Asian Games, surpassing the previous record of 70 medals in 2018.

# %%
manual_testing(news_article)
# Out:
# '\n\nLR Prediction: It is a Fake News \nGBC Prediction: It is a Fake News \nRFC Prediction: It is a Fake News'
